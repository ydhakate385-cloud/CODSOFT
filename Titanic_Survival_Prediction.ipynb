# %%
# Titanic Survival Prediction
### Data science Project

# %%
## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
## 2. Load Dataset

# %%
data = pd.read_csv("titanic.csv")

# %%
data.head()
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
## 3. Data Cleaning

# %%
# Handle missing values
data['Age'] = data['Age'].fillna(data['Age'].mean())
data['Fare'] = data['Fare'].fillna(data['Fare'].mean())

# Convert categorical to numeric
data['Sex'] = data['Sex'].map({'male': 0, 'female': 1})

# %%
## 4. Data Visualization

# %%
sns.countplot(x='Survived', data=data)
plt.show()

# %%
## 5. Feature Selection

# %%
x= data[['Pclass', 'Sex', 'Age', 'Fare']]
y =data['Survived']

# %%
## 6. Train-Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
X_train = X_train.fillna(X_train.mean())
X_test = X_test.fillna(X_test.mean())

# %%
## 7. Model Training

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
## 8. Model Evaluation

# %%
from sklearn.metrics import accuracy_score

y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7988826815642458

# %%
## 9. Conclusion

In this project, a Logistic Regression model was trained on the Titanic dataset
to predict passenger survival. After data cleaning, visualization, and feature
selection, the model achieved an accuracy of approximately 80%.
